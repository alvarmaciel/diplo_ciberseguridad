# %%
import requests
import base64
from typing import Tuple

YOUR_EMAIL = "alvarmaciel@gmail.com"

# URL base del desafío
BASE_URL = f"https://ciberseguridad.diplomatura.unc.edu.ar/cripto/ecb-decrypt/{YOUR_EMAIL}/encrypt"

print(f"URL configurada: {BASE_URL}")
# Out:
# URL configurada: https://ciberseguridad.diplomatura.unc.edu.ar/cripto/ecb-decrypt/alvarmaciel@gmail.com/encrypt

# %%
def get_message(message: str) -> bytes:
    """
    Registra un usuario y obtiene el perfil cifrado.
    
    Args:
        message: mensaje en base64
    
    Returns:
        ciphertext
    """
    
    # Hacer POST request
    response = requests.post(
        BASE_URL,
        files={
            'message': message,
        }
    )
    
    if response.status_code != 200:
        raise Exception(f"Error en la petición: {response.status_code}\n{response.text}")
    
    # Decodificar respuesta base64
    encrypted_message = base64.b64decode(response.text.strip())
    
    return encrypted_message

def response_analysis(ciphertext):
    block_size = 16
    blocks = [ciphertext[i:i+block_size] for i in range(0, len(ciphertext), block_size)]
    print(f"Total bloques: {len(blocks)}")
    
    for i, block in enumerate(blocks):
        print(f"Bloque {i}: {block.hex()}")
    return blocks

# %%
cipher1 = get_message(base64.b64encode(b'A' * 15).decode())
cipher2 = get_message(base64.b64encode(b'A' * 14).decode())

print(f"15 A's, bloque 0: {cipher1[:16].hex()}")
print(f"14 A's, bloque 0: {cipher2[:16].hex()}")
# Out:
# 15 A's, bloque 0: fff9183484a7627c68cd52682af55633
# 14 A's, bloque 0: 52ce51a5d82dbcfd0e4025c6c1257e4c

# %%
encrypted = get_message(base64.b64encode(b'A' * 15).decode())
response_analysis(encrypted)
# Out:
# Total bloques: 10
# Bloque 0: fff9183484a7627c68cd52682af55633
# Bloque 1: 60758239f561612be0b7b0f0a7595878
# Bloque 2: 9b6a50d7762081c467a3a36d16d99ded
# Bloque 3: de8828151c98348e55abe4e16da0d894
# Bloque 4: 50ebee8a67fe998ee9b2b6b6ffba6a02
# Bloque 5: 668a9e2300d0dcdb6caf5586628eb6a1
# Bloque 6: 0c80791bdc74e156b2fc062fdeb711c5
# Bloque 7: 2c5d40cb3b8b4b1bbb67e5f939059bd6
# Bloque 8: 65a95ceff405b5ab17054bd0b4bf16fa
# Bloque 9: 99926bf7ae70ca2fd166c93448fa5275
# [b'\xff\xf9\x184\x84\xa7b|h\xcdRh*\xf5V3',
#  b'`u\x829\xf5aa+\xe0\xb7\xb0\xf0\xa7YXx',
#  b'\x9bjP\xd7v \x81\xc4g\xa3\xa3m\x16\xd9\x9d\xed',
#  b'\xde\x88(\x15\x1c\x984\x8eU\xab\xe4\xe1m\xa0\xd8\x94',
#  b'P\xeb\xee\x8ag\xfe\x99\x8e\xe9\xb2\xb6\xb6\xff\xbaj\x02',
#  b'f\x8a\x9e#\x00\xd0\xdc\xdbl\xafU\x86b\x8e\xb6\xa1',
#  b'\x0c\x80y\x1b\xdct\xe1V\xb2\xfc\x06/\xde\xb7\x11\xc5',
#  b',]@\xcb;\x8bK\x1b\xbbg\xe5\xf99\x05\x9b\xd6',
#  b'e\xa9\\\xef\xf4\x05\xb5\xab\x17\x05K\xd0\xb4\xbf\x16\xfa',
#  b'\x99\x92k\xf7\xaep\xca/\xd1f\xc94H\xfaRu']

# %%
def find_secret_byte(email, known_secret, byte_position):
    """
    Encuentra un byte específico del secreto.
    
    Args:
        email: tu email
        known_secret: bytes del secreto ya descubiertos (como bytes)
        byte_position: posición del byte a descubrir (0-indexed)
    
    Returns:
        El byte encontrado o None
    """
    # Calcular cuántas 'A's necesitamos para alinear
    num_as = 15 - (byte_position % 16)
    prefix = b'A' * num_as
    
    # Determinar en qué bloque está este byte
    target_block_index = byte_position // 16
    
    # Paso 1: Obtener el bloque objetivo (con el byte desconocido)
    target_ciphertext = get_message(base64.b64encode(prefix).decode())
    blocks = [target_ciphertext[i:i+16] for i in range(0, len(target_ciphertext), 16)]
    target_block = blocks[target_block_index]
    
    print(f"Buscando byte {byte_position}, usando {num_as} A's, comparando bloque {target_block_index}")
    print(f"Target block: {target_block.hex()}")
    
    # Paso 2: Probar cada byte posible
    for byte_val in range(256):
        # Construir: prefix + conocido + candidato
        test_message = prefix + known_secret + bytes([byte_val])
        test_ciphertext = get_message(base64.b64encode(test_message).decode())
        test_blocks = [test_ciphertext[i:i+16] for i in range(0, len(test_ciphertext), 16)]
        test_block = test_blocks[target_block_index]
        
        if test_block == target_block:
            char = chr(byte_val) if 32 <= byte_val < 127 else f'\\x{byte_val:02x}'
            print(f"✓ Encontrado: {char}")
            return bytes([byte_val])
    
    print("✗ No encontrado")
    return None

# %%
def recover_full_secret(email, secret_length):
    """
    Recupera el secreto completo byte por byte.
    """
    known_secret = b""
    
    for position in range(secret_length):
        print(f"\n--- Byte {position + 1}/{secret_length} ---")
        byte = find_secret_byte(email, known_secret, position)
        
        if byte is None:
            print(f"Fallo en posición {position}")
            break
        
        known_secret += byte
        
        # Mostrar progreso cada 16 bytes
        if (position + 1) % 16 == 0:
            print(f"\nProgreso ({position + 1} bytes):")
            print(f"Hex: {known_secret.hex()}")
            try:
                print(f"ASCII: {known_secret.decode('ascii', errors='replace')}")
            except:
                print("ASCII: (no decodificable)")
    
    return known_secret

# Ejecutar
secret = recover_full_secret("YOUR_EMAIL", 128)
print(f"\n\n=== SECRETO COMPLETO ===")
print(f"Hex: {secret.hex()}")
print(f"ASCII: {secret}")
# Out:
# --- Byte 1/128 ---
# Buscando byte 0, usando 15 A's, comparando bloque 0
# Target block: fff9183484a7627c68cd52682af55633
# ✓ Encontrado: A
#
# --- Byte 2/128 ---
# Buscando byte 1, usando 14 A's, comparando bloque 0
# Target block: 52ce51a5d82dbcfd0e4025c6c1257e4c
# ✓ Encontrado: l
#
# --- Byte 3/128 ---
# Buscando byte 2, usando 13 A's, comparando bloque 0
# Target block: 3c68419d48586986e8ff46d94ded6279
# ✓ Encontrado: l
#
# --- Byte 4/128 ---
# Buscando byte 3, usando 12 A's, comparando bloque 0
# Target block: 1b38f17107fe807a1637302b7718098d
# ✓ Encontrado:
#
# --- Byte 5/128 ---
# Buscando byte 4, usando 11 A's, comparando bloque 0
# Target block: 3a0d35bf757feed824bd9a3dab9c224d
# ✓ Encontrado: G
#
# --- Byte 6/128 ---
# Buscando byte 5, usando 10 A's, comparando bloque 0
# Target block: 8d70130874a13f21182419883fa67cd1
# ✓ Encontrado: o
#
# --- Byte 7/128 ---
# Buscando byte 6, usando 9 A's, comparando bloque 0
# Target block: ac95fc863a5993ab18a3fe3fc48b1a55
# ✓ Encontrado: d
#
# --- Byte 8/128 ---
# Buscando byte 7, usando 8 A's, comparando bloque 0
# Target block: f71f3677407b3d4021f4dcaaaeb5dfcc
# ✓ Encontrado: '
#
# --- Byte 9/128 ---
# Buscando byte 8, usando 7 A's, comparando bloque 0
# Target block: f7dfbea2ac7950e287e1962a53d813be
# ✓ Encontrado: s
#
# --- Byte 10/128 ---
# Buscando byte 9, usando 6 A's, comparando bloque 0
# Target block: 76089dc9cced645142cc55669242043b
# ✓ Encontrado:
#
# --- Byte 11/128 ---
# Buscando byte 10, usando 5 A's, comparando bloque 0
# Target block: dceb85d86a9b11d6cf3aec9f1881b192
# ✓ Encontrado: c
#
# --- Byte 12/128 ---
# Buscando byte 11, usando 4 A's, comparando bloque 0
# Target block: 8274590486310f168b1724403ff0296c
# ✓ Encontrado: h
#
# --- Byte 13/128 ---
# Buscando byte 12, usando 3 A's, comparando bloque 0
# Target block: 0bca0e954d53ae9501ebcc2ba0e8d4f6
# ✓ Encontrado: i
#
# --- Byte 14/128 ---
# Buscando byte 13, usando 2 A's, comparando bloque 0
# Target block: 61f646ff9d44fe4aebd6a5f80388317e
# ✓ Encontrado: l
#
# --- Byte 15/128 ---
# Buscando byte 14, usando 1 A's, comparando bloque 0
# Target block: a7733b9b16ffe12750de219b503244fb
# ✓ Encontrado: d
#
# --- Byte 16/128 ---
# Buscando byte 15, usando 0 A's, comparando bloque 0
# Target block: 6f271d4a2413ff1a63138db3da095703
# ✓ Encontrado: r
#
# Progreso (16 bytes):
# Hex: 416c6c20476f642773206368696c6472
# ASCII: All God's childr
#
# --- Byte 17/128 ---
# Buscando byte 16, usando 15 A's, comparando bloque 1
# Target block: 60758239f561612be0b7b0f0a7595878
# ✓ Encontrado: e
#
# --- Byte 18/128 ---
# Buscando byte 17, usando 14 A's, comparando bloque 1
# Target block: 820e8d24704dfd73d248fc453a1a3bc7
# ✓ Encontrado: n
#
# --- Byte 19/128 ---
# Buscando byte 18, usando 13 A's, comparando bloque 1
# Target block: d360a0835262a665f87d12f28a5f9e1e
# ✓ Encontrado:
#
# --- Byte 20/128 ---
# Buscando byte 19, usando 12 A's, comparando bloque 1
# Target block: 2c2e6b83aa1c6dbd48aa11e16a2eaee6
# ✓ Encontrado: a
#
# --- Byte 21/128 ---
# Buscando byte 20, usando 11 A's, comparando bloque 1
# Target block: 7f4343ad176cb7b33f88542c284e3ab0
# ✓ Encontrado: r
#
# --- Byte 22/128 ---
# Buscando byte 21, usando 10 A's, comparando bloque 1
# Target block: 50ebee8a67fe998ee9b2b6b6ffba6a02
# ✓ Encontrado: e
#
# --- Byte 23/128 ---
# Buscando byte 22, usando 9 A's, comparando bloque 1
# Target block: 3834576883deed1ee8403cdd27e47983
# ✓ Encontrado:
#
# --- Byte 24/128 ---
# Buscando byte 23, usando 8 A's, comparando bloque 1
# Target block: 4d1bcb30b36d2d2ecedb3bd0aecc5c4f
# ✓ Encontrado: n
#
# --- Byte 25/128 ---
# Buscando byte 24, usando 7 A's, comparando bloque 1
# Target block: 141c7be95e0533204993e44dd6f96e61
# ✓ Encontrado: o
#
# --- Byte 26/128 ---
# Buscando byte 25, usando 6 A's, comparando bloque 1
# Target block: 93a05f71e1a4d02443c91e5f5e9c7ecb
# ✓ Encontrado: t
#
# --- Byte 27/128 ---
# Buscando byte 26, usando 5 A's, comparando bloque 1
# Target block: 367cabdb25054d6072dd22e5c23fcacc
# ✓ Encontrado:
#
# --- Byte 28/128 ---
# Buscando byte 27, usando 4 A's, comparando bloque 1
# Target block: f1695235fc8138ed493b9f533dca63af
# ✓ Encontrado: b
#
# --- Byte 29/128 ---
# Buscando byte 28, usando 3 A's, comparando bloque 1
# Target block: a91af2f2409e77e08740c2e65e9d7b1c
# ✓ Encontrado: e
#
# --- Byte 30/128 ---
# Buscando byte 29, usando 2 A's, comparando bloque 1
# Target block: fe7045fab4e79e25828983e2bd4578fe
# ✓ Encontrado: a
#
# --- Byte 31/128 ---
# Buscando byte 30, usando 1 A's, comparando bloque 1
# Target block: 00b36aa7bb3b9e8f6b2044f5a83a85a6
# ✓ Encontrado: u
#
# --- Byte 32/128 ---
# Buscando byte 31, usando 0 A's, comparando bloque 1
# Target block: d3df5f1a7c875b6a77a2543f44747e6e
# ✓ Encontrado: t
#
# Progreso (32 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f74206265617574
# ASCII: All God's children are not beaut
#
# --- Byte 33/128 ---
# Buscando byte 32, usando 15 A's, comparando bloque 2
# Target block: 9b6a50d7762081c467a3a36d16d99ded
# ✓ Encontrado: i
#
# --- Byte 34/128 ---
# Buscando byte 33, usando 14 A's, comparando bloque 2
# Target block: fe447f69637d69d9017dc30d49469d4a
# ✓ Encontrado: f
#
# --- Byte 35/128 ---
# Buscando byte 34, usando 13 A's, comparando bloque 2
# Target block: 3c200e27a7ebe8dcb624bb2cbb3092e9
# ✓ Encontrado: u
#
# --- Byte 36/128 ---
# Buscando byte 35, usando 12 A's, comparando bloque 2
# Target block: 66ea86ca44b9a3de4ca56f398d7a7dbe
# ✓ Encontrado: l
#
# --- Byte 37/128 ---
# Buscando byte 36, usando 11 A's, comparando bloque 2
# Target block: 69497ba5e857d25b130dde38c812d2ce
# ✓ Encontrado: .
#
# --- Byte 38/128 ---
# Buscando byte 37, usando 10 A's, comparando bloque 2
# Target block: f07b6d7f02514318d243b06c80368329
# ✓ Encontrado:
#
# --- Byte 39/128 ---
# Buscando byte 38, usando 9 A's, comparando bloque 2
# Target block: 6de91a7ef9f3f332494bbdc22d1e08d7
# ✓ Encontrado:
#
# --- Byte 40/128 ---
# Buscando byte 39, usando 8 A's, comparando bloque 2
# Target block: 65e672225eb5f64d73872e623768466b
# ✓ Encontrado: M
#
# --- Byte 41/128 ---
# Buscando byte 40, usando 7 A's, comparando bloque 2
# Target block: ad2ce9ffc8d54886e77a01531b53cd53
# ✓ Encontrado: o
#
# --- Byte 42/128 ---
# Buscando byte 41, usando 6 A's, comparando bloque 2
# Target block: 26dd0934cd0b095a1baa8514e29c7d35
# ✓ Encontrado: s
#
# --- Byte 43/128 ---
# Buscando byte 42, usando 5 A's, comparando bloque 2
# Target block: 7c31f74bfbeebafe5ea064db4fd25efc
# ✓ Encontrado: t
#
# --- Byte 44/128 ---
# Buscando byte 43, usando 4 A's, comparando bloque 2
# Target block: 0fbb2803334e460ddaa4284212192084
# ✓ Encontrado:
#
# --- Byte 45/128 ---
# Buscando byte 44, usando 3 A's, comparando bloque 2
# Target block: 7ebe3c9b250174253ca7e83d66ff1f36
# ✓ Encontrado: o
#
# --- Byte 46/128 ---
# Buscando byte 45, usando 2 A's, comparando bloque 2
# Target block: 7405b066f61027a54de5ac97d0a1ea81
# ✓ Encontrado: f
#
# --- Byte 47/128 ---
# Buscando byte 46, usando 1 A's, comparando bloque 2
# Target block: 01174b326ef2957a9e79c9ae2414734b
# ✓ Encontrado:
#
# --- Byte 48/128 ---
# Buscando byte 47, usando 0 A's, comparando bloque 2
# Target block: 2de1098cbe4002e1c69787734e2ef96c
# ✓ Encontrado: G
#
# Progreso (48 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f662047
# ASCII: All God's children are not beautiful.  Most of G
#
# --- Byte 49/128 ---
# Buscando byte 48, usando 15 A's, comparando bloque 3
# Target block: de8828151c98348e55abe4e16da0d894
# ✓ Encontrado: o
#
# --- Byte 50/128 ---
# Buscando byte 49, usando 14 A's, comparando bloque 3
# Target block: a8cc9b5ac1d4203756d5b6560c64300e
# ✓ Encontrado: d
#
# --- Byte 51/128 ---
# Buscando byte 50, usando 13 A's, comparando bloque 3
# Target block: c2e90c3cd42ab01102662219605c80f4
# ✓ Encontrado: '
#
# --- Byte 52/128 ---
# Buscando byte 51, usando 12 A's, comparando bloque 3
# Target block: a9aa482b14fc34c5e86b9cfe4d8e4efe
# ✓ Encontrado: s
#
# --- Byte 53/128 ---
# Buscando byte 52, usando 11 A's, comparando bloque 3
# Target block: 0e71b71a6e728a3e9fd2344493358d92
# ✓ Encontrado:
#
# --- Byte 54/128 ---
# Buscando byte 53, usando 10 A's, comparando bloque 3
# Target block: 66eeb10cbf3f3cd54a15a1cb5ba2dfab
# ✓ Encontrado: c
#
# --- Byte 55/128 ---
# Buscando byte 54, usando 9 A's, comparando bloque 3
# Target block: eff595e1b8cc7c489ebc404c366e2a51
# ✓ Encontrado: h
#
# --- Byte 56/128 ---
# Buscando byte 55, usando 8 A's, comparando bloque 3
# Target block: 7ed181d9fb0909fc4f60e399182e8f0f
# ✓ Encontrado: i
#
# --- Byte 57/128 ---
# Buscando byte 56, usando 7 A's, comparando bloque 3
# Target block: 1c7c649bd8db6ef37578931395b6b6c9
# ✓ Encontrado: l
#
# --- Byte 58/128 ---
# Buscando byte 57, usando 6 A's, comparando bloque 3
# Target block: e3beac3668b222f005abde175e12d142
# ✓ Encontrado: d
#
# --- Byte 59/128 ---
# Buscando byte 58, usando 5 A's, comparando bloque 3
# Target block: dc4c7a7ed0781f407dadcae62346cbd8
# ✓ Encontrado: r
#
# --- Byte 60/128 ---
# Buscando byte 59, usando 4 A's, comparando bloque 3
# Target block: 4936783c6041ec7fce70ddf88eb4c889
# ✓ Encontrado: e
#
# --- Byte 61/128 ---
# Buscando byte 60, usando 3 A's, comparando bloque 3
# Target block: f2ad62bb9211195be3441e4c103a3aa9
# ✓ Encontrado: n
#
# --- Byte 62/128 ---
# Buscando byte 61, usando 2 A's, comparando bloque 3
# Target block: d360a0835262a665f87d12f28a5f9e1e
# ✓ Encontrado:
#
# --- Byte 63/128 ---
# Buscando byte 62, usando 1 A's, comparando bloque 3
# Target block: 2c2e6b83aa1c6dbd48aa11e16a2eaee6
# ✓ Encontrado: a
#
# --- Byte 64/128 ---
# Buscando byte 63, usando 0 A's, comparando bloque 3
# Target block: 7f4343ad176cb7b33f88542c284e3ab0
# ✓ Encontrado: r
#
# Progreso (64 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f6620476f642773206368696c6472656e206172
# ASCII: All God's children are not beautiful.  Most of God's children ar
#
# --- Byte 65/128 ---
# Buscando byte 64, usando 15 A's, comparando bloque 4
# Target block: 50ebee8a67fe998ee9b2b6b6ffba6a02
# ✓ Encontrado: e
#
# --- Byte 66/128 ---
# Buscando byte 65, usando 14 A's, comparando bloque 4
# Target block: 8540f3f6861ab67cf23e80277c7b62c0
# ✓ Encontrado: ,
#
# --- Byte 67/128 ---
# Buscando byte 66, usando 13 A's, comparando bloque 4
# Target block: 1d7ff465f5e9ee5dd7323361a7a4d75e
# ✓ Encontrado:
#
# --- Byte 68/128 ---
# Buscando byte 67, usando 12 A's, comparando bloque 4
# Target block: 35ef7afb6d60982a367a5f67686eded1
# ✓ Encontrado: i
#
# --- Byte 69/128 ---
# Buscando byte 68, usando 11 A's, comparando bloque 4
# Target block: bb7370e0c2c4e7609ef20ce35dc3520f
# ✓ Encontrado: n
#
# --- Byte 70/128 ---
# Buscando byte 69, usando 10 A's, comparando bloque 4
# Target block: 0a5bcea07024a68d3af16dd9cb154236
# ✓ Encontrado:
#
# --- Byte 71/128 ---
# Buscando byte 70, usando 9 A's, comparando bloque 4
# Target block: 797bcf0e7384020df427f6021b478772
# ✓ Encontrado: f
#
# --- Byte 72/128 ---
# Buscando byte 71, usando 8 A's, comparando bloque 4
# Target block: a84711748788c7fd097b662073a07cb1
# ✓ Encontrado: a
#
# --- Byte 73/128 ---
# Buscando byte 72, usando 7 A's, comparando bloque 4
# Target block: bd09ffdfdd2ba666c27cb9439dfca2c4
# ✓ Encontrado: c
#
# --- Byte 74/128 ---
# Buscando byte 73, usando 6 A's, comparando bloque 4
# Target block: 585aa245694f5b4c0c21392ae4f36e96
# ✓ Encontrado: t
#
# --- Byte 75/128 ---
# Buscando byte 74, usando 5 A's, comparando bloque 4
# Target block: 2adaf69bcba976db750d7556c62e698e
# ✓ Encontrado: ,
#
# --- Byte 76/128 ---
# Buscando byte 75, usando 4 A's, comparando bloque 4
# Target block: 0cdd545765fc231c1d0f69f7180b9c5f
# ✓ Encontrado: \x0a
#
# --- Byte 77/128 ---
# Buscando byte 76, usando 3 A's, comparando bloque 4
# Target block: 7f0fac9f8d30b7009636a9206d2fed70
# ✓ Encontrado: b
#
# --- Byte 78/128 ---
# Buscando byte 77, usando 2 A's, comparando bloque 4
# Target block: 8c776b09d4ecfd4f3da5da6b13bd2769
# ✓ Encontrado: a
#
# --- Byte 79/128 ---
# Buscando byte 78, usando 1 A's, comparando bloque 4
# Target block: 5313f5e37e6bc0590ce31fa4bb85a315
# ✓ Encontrado: r
#
# --- Byte 80/128 ---
# Buscando byte 79, usando 0 A's, comparando bloque 4
# Target block: f3bc79f00e87cb3eb7ef8e126db6121b
# ✓ Encontrado: e
#
# Progreso (80 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f6620476f642773206368696c6472656e206172652c20696e20666163742c0a62617265
# ASCII: All God's children are not beautiful.  Most of God's children are, in fact,
# bare
#
# --- Byte 81/128 ---
# Buscando byte 80, usando 15 A's, comparando bloque 5
# Target block: 668a9e2300d0dcdb6caf5586628eb6a1
# ✓ Encontrado: l
#
# --- Byte 82/128 ---
# Buscando byte 81, usando 14 A's, comparando bloque 5
# Target block: 0d8648890a3922053606e47f5217fb47
# ✓ Encontrado: y
#
# --- Byte 83/128 ---
# Buscando byte 82, usando 13 A's, comparando bloque 5
# Target block: a73cf2c5fc32a358ce141ce537c239a7
# ✓ Encontrado:
#
# --- Byte 84/128 ---
# Buscando byte 83, usando 12 A's, comparando bloque 5
# Target block: 30548890bd3e20860e7047cb166b8226
# ✓ Encontrado: p
#
# --- Byte 85/128 ---
# Buscando byte 84, usando 11 A's, comparando bloque 5
# Target block: 76918c9c52b4d13b4e62417097894811
# ✓ Encontrado: r
#
# --- Byte 86/128 ---
# Buscando byte 85, usando 10 A's, comparando bloque 5
# Target block: 55f42c31d41969c9a845b66366a537d0
# ✓ Encontrado: e
#
# --- Byte 87/128 ---
# Buscando byte 86, usando 9 A's, comparando bloque 5
# Target block: 19688f2e919af44a3660479fc97145f5
# ✓ Encontrado: s
#
# --- Byte 88/128 ---
# Buscando byte 87, usando 8 A's, comparando bloque 5
# Target block: ff17371ae12c331a1183ccd8bab31c29
# ✓ Encontrado: e
#
# --- Byte 89/128 ---
# Buscando byte 88, usando 7 A's, comparando bloque 5
# Target block: 50cf3b7d0b903ba75a1ce233d23eb69b
# ✓ Encontrado: n
#
# --- Byte 90/128 ---
# Buscando byte 89, usando 6 A's, comparando bloque 5
# Target block: 942ce41a12a862e88b4d1bbf8a89c1b1
# ✓ Encontrado: t
#
# --- Byte 91/128 ---
# Buscando byte 90, usando 5 A's, comparando bloque 5
# Target block: 006009ca2d971cae9dfa7f72a233b367
# ✓ Encontrado: a
#
# --- Byte 92/128 ---
# Buscando byte 91, usando 4 A's, comparando bloque 5
# Target block: 215d8032cfb4dfa5199bcc639dfe3434
# ✓ Encontrado: b
#
# --- Byte 93/128 ---
# Buscando byte 92, usando 3 A's, comparando bloque 5
# Target block: 2e82fed126ae4c427681bc1fd4516ef3
# ✓ Encontrado: l
#
# --- Byte 94/128 ---
# Buscando byte 93, usando 2 A's, comparando bloque 5
# Target block: ab846847a76a2f762793a3cf77f82dbf
# ✓ Encontrado: e
#
# --- Byte 95/128 ---
# Buscando byte 94, usando 1 A's, comparando bloque 5
# Target block: add0bb34fd9c1ba593b7edfa77da58f0
# ✓ Encontrado: .
#
# --- Byte 96/128 ---
# Buscando byte 95, usando 0 A's, comparando bloque 5
# Target block: 4aa90ffea7a5d48449a025884c2af99d
# ✓ Encontrado: \x0a
#
# Progreso (96 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f6620476f642773206368696c6472656e206172652c20696e20666163742c0a626172656c792070726573656e7461626c652e0a
# ASCII: All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
#
#
# --- Byte 97/128 ---
# Buscando byte 96, usando 15 A's, comparando bloque 6
# Target block: 0c80791bdc74e156b2fc062fdeb711c5
# ✓ Encontrado: \x09
#
# --- Byte 98/128 ---
# Buscando byte 97, usando 14 A's, comparando bloque 6
# Target block: 8239179aeaaf73e7e74e55f0cd61c1ac
# ✓ Encontrado: \x09
#
# --- Byte 99/128 ---
# Buscando byte 98, usando 13 A's, comparando bloque 6
# Target block: 6c293e222ff83befbeead0e7ea70d42c
# ✓ Encontrado: -
#
# --- Byte 100/128 ---
# Buscando byte 99, usando 12 A's, comparando bloque 6
# Target block: 884463b72c8c9dca131d05558dcd47d3
# ✓ Encontrado: -
#
# --- Byte 101/128 ---
# Buscando byte 100, usando 11 A's, comparando bloque 6
# Target block: 97c0d9d611c041b2442233f2d596d67a
# ✓ Encontrado:
#
# --- Byte 102/128 ---
# Buscando byte 101, usando 10 A's, comparando bloque 6
# Target block: 5b870bb45989ebefe65d54c7640e0eeb
# ✓ Encontrado: F
#
# --- Byte 103/128 ---
# Buscando byte 102, usando 9 A's, comparando bloque 6
# Target block: 5b13838325d9dc97f6c736f6764c87a1
# ✓ Encontrado: r
#
# --- Byte 104/128 ---
# Buscando byte 103, usando 8 A's, comparando bloque 6
# Target block: f5df393eebb3eda4614ebe1cc956eaa5
# ✓ Encontrado: a
#
# --- Byte 105/128 ---
# Buscando byte 104, usando 7 A's, comparando bloque 6
# Target block: 907cded320a3a3d62b86ce6391e776a1
# ✓ Encontrado: n
#
# --- Byte 106/128 ---
# Buscando byte 105, usando 6 A's, comparando bloque 6
# Target block: 15f9b2d09e6edb873f91c26eefc6f6cb
# ✓ Encontrado:
#
# --- Byte 107/128 ---
# Buscando byte 106, usando 5 A's, comparando bloque 6
# Target block: 97adaf76b5b383f8bbee8a5c5cb5d7ef
# ✓ Encontrado: L
#
# --- Byte 108/128 ---
# Buscando byte 107, usando 4 A's, comparando bloque 6
# Target block: 81dc9d9f46226f4d9d1411a409be3d73
# ✓ Encontrado: e
#
# --- Byte 109/128 ---
# Buscando byte 108, usando 3 A's, comparando bloque 6
# Target block: f37b33a480690eedfa36617855b37a90
# ✓ Encontrado: b
#
# --- Byte 110/128 ---
# Buscando byte 109, usando 2 A's, comparando bloque 6
# Target block: bb3ee3cb7eca286659e0ed70000305eb
# ✓ Encontrado: o
#
# --- Byte 111/128 ---
# Buscando byte 110, usando 1 A's, comparando bloque 6
# Target block: 6e46b8a1c3615553d93097b2e87e9f09
# ✓ Encontrado: w
#
# --- Byte 112/128 ---
# Buscando byte 111, usando 0 A's, comparando bloque 6
# Target block: 2a595d1f75d5c457d0f13a4131c32355
# ✓ Encontrado: i
#
# Progreso (112 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f6620476f642773206368696c6472656e206172652c20696e20666163742c0a626172656c792070726573656e7461626c652e0a09092d2d204672616e204c65626f7769
# ASCII: All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
# 		-- Fran Lebowi
#
# --- Byte 113/128 ---
# Buscando byte 112, usando 15 A's, comparando bloque 7
# Target block: 2c5d40cb3b8b4b1bbb67e5f939059bd6
# ✓ Encontrado: t
#
# --- Byte 114/128 ---
# Buscando byte 113, usando 14 A's, comparando bloque 7
# Target block: 32f55df1c18c9a0817c2738a551f7959
# ✓ Encontrado: z
#
# --- Byte 115/128 ---
# Buscando byte 114, usando 13 A's, comparando bloque 7
# Target block: 92a5e3f561f3f673da20394c10a71288
# ✓ Encontrado: ,
#
# --- Byte 116/128 ---
# Buscando byte 115, usando 12 A's, comparando bloque 7
# Target block: d5cc5a6107fcefb1e056649dd676195c
# ✓ Encontrado:
#
# --- Byte 117/128 ---
# Buscando byte 116, usando 11 A's, comparando bloque 7
# Target block: 4d60b97c9d5581ebf0619687562fee55
# ✓ Encontrado: "
#
# --- Byte 118/128 ---
# Buscando byte 117, usando 10 A's, comparando bloque 7
# Target block: 7aabf08a360eea2f3791dbdeef82750a
# ✓ Encontrado: M
#
# --- Byte 119/128 ---
# Buscando byte 118, usando 9 A's, comparando bloque 7
# Target block: a129ba0d899018aa7c1be8492276b050
# ✓ Encontrado: e
#
# --- Byte 120/128 ---
# Buscando byte 119, usando 8 A's, comparando bloque 7
# Target block: c8d6a02822e1e4fed50e2e897091314c
# ✓ Encontrado: t
#
# --- Byte 121/128 ---
# Buscando byte 120, usando 7 A's, comparando bloque 7
# Target block: 68437c9aee710ef7139291215fdd7bc8
# ✓ Encontrado: r
#
# --- Byte 122/128 ---
# Buscando byte 121, usando 6 A's, comparando bloque 7
# Target block: 818550de06c43d1d9502b3f041166ccb
# ✓ Encontrado: o
#
# --- Byte 123/128 ---
# Buscando byte 122, usando 5 A's, comparando bloque 7
# Target block: 7bfdc5eb1c88f0bed55afd52f9405830
# ✓ Encontrado: p
#
# --- Byte 124/128 ---
# Buscando byte 123, usando 4 A's, comparando bloque 7
# Target block: e0945e62ada4282e291c09deff64eae5
# ✓ Encontrado: o
#
# --- Byte 125/128 ---
# Buscando byte 124, usando 3 A's, comparando bloque 7
# Target block: 1f105ef3839ab10a94cb4df24afb6994
# ✓ Encontrado: l
#
# --- Byte 126/128 ---
# Buscando byte 125, usando 2 A's, comparando bloque 7
# Target block: 4b0fbac31b92db663536ee8bfeda8170
# ✓ Encontrado: i
#
# --- Byte 127/128 ---
# Buscando byte 126, usando 1 A's, comparando bloque 7
# Target block: 85918a9d7d5dea1ced492639d7bba5f4
# ✓ Encontrado: t
#
# --- Byte 128/128 ---
# Buscando byte 127, usando 0 A's, comparando bloque 7
# Target block: 0b557aa86bc0d69f5d659a30bf3227bb
# ✓ Encontrado: a
#
# Progreso (128 bytes):
# Hex: 
# ASCII: All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
# 		-- Fran Lebowitz, "Metropolita
#
#
# === SECRETO COMPLETO ===
# Hex: 
# ASCII: b'All God\'s children are not beautiful.  Most of God\'s children are, in fact,\nbarely presentable.\n\t\t-- Fran Lebowitz, "Metropolita'

# %%
secret_extended = recover_full_secret(YOUR_EMAIL, 144)
print(secret_extended.decode('utf-8', errors='replace'))
# Out:
# --- Byte 1/144 ---
# Buscando byte 0, usando 15 A's, comparando bloque 0
# Target block: fff9183484a7627c68cd52682af55633
# ✓ Encontrado: A
#
# --- Byte 2/144 ---
# Buscando byte 1, usando 14 A's, comparando bloque 0
# Target block: 52ce51a5d82dbcfd0e4025c6c1257e4c
# ✓ Encontrado: l
#
# --- Byte 3/144 ---
# Buscando byte 2, usando 13 A's, comparando bloque 0
# Target block: 3c68419d48586986e8ff46d94ded6279
# ✓ Encontrado: l
#
# --- Byte 4/144 ---
# Buscando byte 3, usando 12 A's, comparando bloque 0
# Target block: 1b38f17107fe807a1637302b7718098d
# ✓ Encontrado:
#
# --- Byte 5/144 ---
# Buscando byte 4, usando 11 A's, comparando bloque 0
# Target block: 3a0d35bf757feed824bd9a3dab9c224d
# ✓ Encontrado: G
#
# --- Byte 6/144 ---
# Buscando byte 5, usando 10 A's, comparando bloque 0
# Target block: 8d70130874a13f21182419883fa67cd1
# ✓ Encontrado: o
#
# --- Byte 7/144 ---
# Buscando byte 6, usando 9 A's, comparando bloque 0
# Target block: ac95fc863a5993ab18a3fe3fc48b1a55
# ✓ Encontrado: d
#
# --- Byte 8/144 ---
# Buscando byte 7, usando 8 A's, comparando bloque 0
# Target block: f71f3677407b3d4021f4dcaaaeb5dfcc
# ✓ Encontrado: '
#
# --- Byte 9/144 ---
# Buscando byte 8, usando 7 A's, comparando bloque 0
# Target block: f7dfbea2ac7950e287e1962a53d813be
# ✓ Encontrado: s
#
# --- Byte 10/144 ---
# Buscando byte 9, usando 6 A's, comparando bloque 0
# Target block: 76089dc9cced645142cc55669242043b
# ✓ Encontrado:
#
# --- Byte 11/144 ---
# Buscando byte 10, usando 5 A's, comparando bloque 0
# Target block: dceb85d86a9b11d6cf3aec9f1881b192
# ✓ Encontrado: c
#
# --- Byte 12/144 ---
# Buscando byte 11, usando 4 A's, comparando bloque 0
# Target block: 8274590486310f168b1724403ff0296c
# ✓ Encontrado: h
#
# --- Byte 13/144 ---
# Buscando byte 12, usando 3 A's, comparando bloque 0
# Target block: 0bca0e954d53ae9501ebcc2ba0e8d4f6
# ✓ Encontrado: i
#
# --- Byte 14/144 ---
# Buscando byte 13, usando 2 A's, comparando bloque 0
# Target block: 61f646ff9d44fe4aebd6a5f80388317e
# ✓ Encontrado: l
#
# --- Byte 15/144 ---
# Buscando byte 14, usando 1 A's, comparando bloque 0
# Target block: a7733b9b16ffe12750de219b503244fb
# ✓ Encontrado: d
#
# --- Byte 16/144 ---
# Buscando byte 15, usando 0 A's, comparando bloque 0
# Target block: 6f271d4a2413ff1a63138db3da095703
# ✓ Encontrado: r
#
# Progreso (16 bytes):
# Hex: 416c6c20476f642773206368696c6472
# ASCII: All God's childr
#
# --- Byte 17/144 ---
# Buscando byte 16, usando 15 A's, comparando bloque 1
# Target block: 60758239f561612be0b7b0f0a7595878
# ✓ Encontrado: e
#
# --- Byte 18/144 ---
# Buscando byte 17, usando 14 A's, comparando bloque 1
# Target block: 820e8d24704dfd73d248fc453a1a3bc7
# ✓ Encontrado: n
#
# --- Byte 19/144 ---
# Buscando byte 18, usando 13 A's, comparando bloque 1
# Target block: d360a0835262a665f87d12f28a5f9e1e
# ✓ Encontrado:
#
# --- Byte 20/144 ---
# Buscando byte 19, usando 12 A's, comparando bloque 1
# Target block: 2c2e6b83aa1c6dbd48aa11e16a2eaee6
# ✓ Encontrado: a
#
# --- Byte 21/144 ---
# Buscando byte 20, usando 11 A's, comparando bloque 1
# Target block: 7f4343ad176cb7b33f88542c284e3ab0
# ✓ Encontrado: r
#
# --- Byte 22/144 ---
# Buscando byte 21, usando 10 A's, comparando bloque 1
# Target block: 50ebee8a67fe998ee9b2b6b6ffba6a02
# ✓ Encontrado: e
#
# --- Byte 23/144 ---
# Buscando byte 22, usando 9 A's, comparando bloque 1
# Target block: 3834576883deed1ee8403cdd27e47983
# ✓ Encontrado:
#
# --- Byte 24/144 ---
# Buscando byte 23, usando 8 A's, comparando bloque 1
# Target block: 4d1bcb30b36d2d2ecedb3bd0aecc5c4f
# ✓ Encontrado: n
#
# --- Byte 25/144 ---
# Buscando byte 24, usando 7 A's, comparando bloque 1
# Target block: 141c7be95e0533204993e44dd6f96e61
# ✓ Encontrado: o
#
# --- Byte 26/144 ---
# Buscando byte 25, usando 6 A's, comparando bloque 1
# Target block: 93a05f71e1a4d02443c91e5f5e9c7ecb
# ✓ Encontrado: t
#
# --- Byte 27/144 ---
# Buscando byte 26, usando 5 A's, comparando bloque 1
# Target block: 367cabdb25054d6072dd22e5c23fcacc
# ✓ Encontrado:
#
# --- Byte 28/144 ---
# Buscando byte 27, usando 4 A's, comparando bloque 1
# Target block: f1695235fc8138ed493b9f533dca63af
# ✓ Encontrado: b
#
# --- Byte 29/144 ---
# Buscando byte 28, usando 3 A's, comparando bloque 1
# Target block: a91af2f2409e77e08740c2e65e9d7b1c
# ✓ Encontrado: e
#
# --- Byte 30/144 ---
# Buscando byte 29, usando 2 A's, comparando bloque 1
# Target block: fe7045fab4e79e25828983e2bd4578fe
# ✓ Encontrado: a
#
# --- Byte 31/144 ---
# Buscando byte 30, usando 1 A's, comparando bloque 1
# Target block: 00b36aa7bb3b9e8f6b2044f5a83a85a6
# ✓ Encontrado: u
#
# --- Byte 32/144 ---
# Buscando byte 31, usando 0 A's, comparando bloque 1
# Target block: d3df5f1a7c875b6a77a2543f44747e6e
# ✓ Encontrado: t
#
# Progreso (32 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f74206265617574
# ASCII: All God's children are not beaut
#
# --- Byte 33/144 ---
# Buscando byte 32, usando 15 A's, comparando bloque 2
# Target block: 9b6a50d7762081c467a3a36d16d99ded
# ✓ Encontrado: i
#
# --- Byte 34/144 ---
# Buscando byte 33, usando 14 A's, comparando bloque 2
# Target block: fe447f69637d69d9017dc30d49469d4a
# ✓ Encontrado: f
#
# --- Byte 35/144 ---
# Buscando byte 34, usando 13 A's, comparando bloque 2
# Target block: 3c200e27a7ebe8dcb624bb2cbb3092e9
# ✓ Encontrado: u
#
# --- Byte 36/144 ---
# Buscando byte 35, usando 12 A's, comparando bloque 2
# Target block: 66ea86ca44b9a3de4ca56f398d7a7dbe
# ✓ Encontrado: l
#
# --- Byte 37/144 ---
# Buscando byte 36, usando 11 A's, comparando bloque 2
# Target block: 69497ba5e857d25b130dde38c812d2ce
# ✓ Encontrado: .
#
# --- Byte 38/144 ---
# Buscando byte 37, usando 10 A's, comparando bloque 2
# Target block: f07b6d7f02514318d243b06c80368329
# ✓ Encontrado:
#
# --- Byte 39/144 ---
# Buscando byte 38, usando 9 A's, comparando bloque 2
# Target block: 6de91a7ef9f3f332494bbdc22d1e08d7
# ✓ Encontrado:
#
# --- Byte 40/144 ---
# Buscando byte 39, usando 8 A's, comparando bloque 2
# Target block: 65e672225eb5f64d73872e623768466b
# ✓ Encontrado: M
#
# --- Byte 41/144 ---
# Buscando byte 40, usando 7 A's, comparando bloque 2
# Target block: ad2ce9ffc8d54886e77a01531b53cd53
# ✓ Encontrado: o
#
# --- Byte 42/144 ---
# Buscando byte 41, usando 6 A's, comparando bloque 2
# Target block: 26dd0934cd0b095a1baa8514e29c7d35
# ✓ Encontrado: s
#
# --- Byte 43/144 ---
# Buscando byte 42, usando 5 A's, comparando bloque 2
# Target block: 7c31f74bfbeebafe5ea064db4fd25efc
# ✓ Encontrado: t
#
# --- Byte 44/144 ---
# Buscando byte 43, usando 4 A's, comparando bloque 2
# Target block: 0fbb2803334e460ddaa4284212192084
# ✓ Encontrado:
#
# --- Byte 45/144 ---
# Buscando byte 44, usando 3 A's, comparando bloque 2
# Target block: 7ebe3c9b250174253ca7e83d66ff1f36
# ✓ Encontrado: o
#
# --- Byte 46/144 ---
# Buscando byte 45, usando 2 A's, comparando bloque 2
# Target block: 7405b066f61027a54de5ac97d0a1ea81
# ✓ Encontrado: f
#
# --- Byte 47/144 ---
# Buscando byte 46, usando 1 A's, comparando bloque 2
# Target block: 01174b326ef2957a9e79c9ae2414734b
# ✓ Encontrado:
#
# --- Byte 48/144 ---
# Buscando byte 47, usando 0 A's, comparando bloque 2
# Target block: 2de1098cbe4002e1c69787734e2ef96c
# ✓ Encontrado: G
#
# Progreso (48 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f662047
# ASCII: All God's children are not beautiful.  Most of G
#
# --- Byte 49/144 ---
# Buscando byte 48, usando 15 A's, comparando bloque 3
# Target block: de8828151c98348e55abe4e16da0d894
# ✓ Encontrado: o
#
# --- Byte 50/144 ---
# Buscando byte 49, usando 14 A's, comparando bloque 3
# Target block: a8cc9b5ac1d4203756d5b6560c64300e
# ✓ Encontrado: d
#
# --- Byte 51/144 ---
# Buscando byte 50, usando 13 A's, comparando bloque 3
# Target block: c2e90c3cd42ab01102662219605c80f4
# ✓ Encontrado: '
#
# --- Byte 52/144 ---
# Buscando byte 51, usando 12 A's, comparando bloque 3
# Target block: a9aa482b14fc34c5e86b9cfe4d8e4efe
# ✓ Encontrado: s
#
# --- Byte 53/144 ---
# Buscando byte 52, usando 11 A's, comparando bloque 3
# Target block: 0e71b71a6e728a3e9fd2344493358d92
# ✓ Encontrado:
#
# --- Byte 54/144 ---
# Buscando byte 53, usando 10 A's, comparando bloque 3
# Target block: 66eeb10cbf3f3cd54a15a1cb5ba2dfab
# ✓ Encontrado: c
#
# --- Byte 55/144 ---
# Buscando byte 54, usando 9 A's, comparando bloque 3
# Target block: eff595e1b8cc7c489ebc404c366e2a51
# ✓ Encontrado: h
#
# --- Byte 56/144 ---
# Buscando byte 55, usando 8 A's, comparando bloque 3
# Target block: 7ed181d9fb0909fc4f60e399182e8f0f
# ✓ Encontrado: i
#
# --- Byte 57/144 ---
# Buscando byte 56, usando 7 A's, comparando bloque 3
# Target block: 1c7c649bd8db6ef37578931395b6b6c9
# ✓ Encontrado: l
#
# --- Byte 58/144 ---
# Buscando byte 57, usando 6 A's, comparando bloque 3
# Target block: e3beac3668b222f005abde175e12d142
# ✓ Encontrado: d
#
# --- Byte 59/144 ---
# Buscando byte 58, usando 5 A's, comparando bloque 3
# Target block: dc4c7a7ed0781f407dadcae62346cbd8
# ✓ Encontrado: r
#
# --- Byte 60/144 ---
# Buscando byte 59, usando 4 A's, comparando bloque 3
# Target block: 4936783c6041ec7fce70ddf88eb4c889
# ✓ Encontrado: e
#
# --- Byte 61/144 ---
# Buscando byte 60, usando 3 A's, comparando bloque 3
# Target block: f2ad62bb9211195be3441e4c103a3aa9
# ✓ Encontrado: n
#
# --- Byte 62/144 ---
# Buscando byte 61, usando 2 A's, comparando bloque 3
# Target block: d360a0835262a665f87d12f28a5f9e1e
# ✓ Encontrado:
#
# --- Byte 63/144 ---
# Buscando byte 62, usando 1 A's, comparando bloque 3
# Target block: 2c2e6b83aa1c6dbd48aa11e16a2eaee6
# ✓ Encontrado: a
#
# --- Byte 64/144 ---
# Buscando byte 63, usando 0 A's, comparando bloque 3
# Target block: 7f4343ad176cb7b33f88542c284e3ab0
# ✓ Encontrado: r
#
# Progreso (64 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f6620476f642773206368696c6472656e206172
# ASCII: All God's children are not beautiful.  Most of God's children ar
#
# --- Byte 65/144 ---
# Buscando byte 64, usando 15 A's, comparando bloque 4
# Target block: 50ebee8a67fe998ee9b2b6b6ffba6a02
# ✓ Encontrado: e
#
# --- Byte 66/144 ---
# Buscando byte 65, usando 14 A's, comparando bloque 4
# Target block: 8540f3f6861ab67cf23e80277c7b62c0
# ✓ Encontrado: ,
#
# --- Byte 67/144 ---
# Buscando byte 66, usando 13 A's, comparando bloque 4
# Target block: 1d7ff465f5e9ee5dd7323361a7a4d75e
# ✓ Encontrado:
#
# --- Byte 68/144 ---
# Buscando byte 67, usando 12 A's, comparando bloque 4
# Target block: 35ef7afb6d60982a367a5f67686eded1
# ✓ Encontrado: i
#
# --- Byte 69/144 ---
# Buscando byte 68, usando 11 A's, comparando bloque 4
# Target block: bb7370e0c2c4e7609ef20ce35dc3520f
# ✓ Encontrado: n
#
# --- Byte 70/144 ---
# Buscando byte 69, usando 10 A's, comparando bloque 4
# Target block: 0a5bcea07024a68d3af16dd9cb154236
# ✓ Encontrado:
#
# --- Byte 71/144 ---
# Buscando byte 70, usando 9 A's, comparando bloque 4
# Target block: 797bcf0e7384020df427f6021b478772
# ✓ Encontrado: f
#
# --- Byte 72/144 ---
# Buscando byte 71, usando 8 A's, comparando bloque 4
# Target block: a84711748788c7fd097b662073a07cb1
# ✓ Encontrado: a
#
# --- Byte 73/144 ---
# Buscando byte 72, usando 7 A's, comparando bloque 4
# Target block: bd09ffdfdd2ba666c27cb9439dfca2c4
# ✓ Encontrado: c
#
# --- Byte 74/144 ---
# Buscando byte 73, usando 6 A's, comparando bloque 4
# Target block: 585aa245694f5b4c0c21392ae4f36e96
# ✓ Encontrado: t
#
# --- Byte 75/144 ---
# Buscando byte 74, usando 5 A's, comparando bloque 4
# Target block: 2adaf69bcba976db750d7556c62e698e
# ✓ Encontrado: ,
#
# --- Byte 76/144 ---
# Buscando byte 75, usando 4 A's, comparando bloque 4
# Target block: 0cdd545765fc231c1d0f69f7180b9c5f
# ✓ Encontrado: \x0a
#
# --- Byte 77/144 ---
# Buscando byte 76, usando 3 A's, comparando bloque 4
# Target block: 7f0fac9f8d30b7009636a9206d2fed70
# ✓ Encontrado: b
#
# --- Byte 78/144 ---
# Buscando byte 77, usando 2 A's, comparando bloque 4
# Target block: 8c776b09d4ecfd4f3da5da6b13bd2769
# ✓ Encontrado: a
#
# --- Byte 79/144 ---
# Buscando byte 78, usando 1 A's, comparando bloque 4
# Target block: 5313f5e37e6bc0590ce31fa4bb85a315
# ✓ Encontrado: r
#
# --- Byte 80/144 ---
# Buscando byte 79, usando 0 A's, comparando bloque 4
# Target block: f3bc79f00e87cb3eb7ef8e126db6121b
# ✓ Encontrado: e
#
# Progreso (80 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f6620476f642773206368696c6472656e206172652c20696e20666163742c0a62617265
# ASCII: All God's children are not beautiful.  Most of God's children are, in fact,
# bare
#
# --- Byte 81/144 ---
# Buscando byte 80, usando 15 A's, comparando bloque 5
# Target block: 668a9e2300d0dcdb6caf5586628eb6a1
# ✓ Encontrado: l
#
# --- Byte 82/144 ---
# Buscando byte 81, usando 14 A's, comparando bloque 5
# Target block: 0d8648890a3922053606e47f5217fb47
# ✓ Encontrado: y
#
# --- Byte 83/144 ---
# Buscando byte 82, usando 13 A's, comparando bloque 5
# Target block: a73cf2c5fc32a358ce141ce537c239a7
# ✓ Encontrado:
#
# --- Byte 84/144 ---
# Buscando byte 83, usando 12 A's, comparando bloque 5
# Target block: 30548890bd3e20860e7047cb166b8226
# ✓ Encontrado: p
#
# --- Byte 85/144 ---
# Buscando byte 84, usando 11 A's, comparando bloque 5
# Target block: 76918c9c52b4d13b4e62417097894811
# ✓ Encontrado: r
#
# --- Byte 86/144 ---
# Buscando byte 85, usando 10 A's, comparando bloque 5
# Target block: 55f42c31d41969c9a845b66366a537d0
# ✓ Encontrado: e
#
# --- Byte 87/144 ---
# Buscando byte 86, usando 9 A's, comparando bloque 5
# Target block: 19688f2e919af44a3660479fc97145f5
# ✓ Encontrado: s
#
# --- Byte 88/144 ---
# Buscando byte 87, usando 8 A's, comparando bloque 5
# Target block: ff17371ae12c331a1183ccd8bab31c29
# ✓ Encontrado: e
#
# --- Byte 89/144 ---
# Buscando byte 88, usando 7 A's, comparando bloque 5
# Target block: 50cf3b7d0b903ba75a1ce233d23eb69b
# ✓ Encontrado: n
#
# --- Byte 90/144 ---
# Buscando byte 89, usando 6 A's, comparando bloque 5
# Target block: 942ce41a12a862e88b4d1bbf8a89c1b1
# ✓ Encontrado: t
#
# --- Byte 91/144 ---
# Buscando byte 90, usando 5 A's, comparando bloque 5
# Target block: 006009ca2d971cae9dfa7f72a233b367
# ✓ Encontrado: a
#
# --- Byte 92/144 ---
# Buscando byte 91, usando 4 A's, comparando bloque 5
# Target block: 215d8032cfb4dfa5199bcc639dfe3434
# ✓ Encontrado: b
#
# --- Byte 93/144 ---
# Buscando byte 92, usando 3 A's, comparando bloque 5
# Target block: 2e82fed126ae4c427681bc1fd4516ef3
# ✓ Encontrado: l
#
# --- Byte 94/144 ---
# Buscando byte 93, usando 2 A's, comparando bloque 5
# Target block: ab846847a76a2f762793a3cf77f82dbf
# ✓ Encontrado: e
#
# --- Byte 95/144 ---
# Buscando byte 94, usando 1 A's, comparando bloque 5
# Target block: add0bb34fd9c1ba593b7edfa77da58f0
# ✓ Encontrado: .
#
# --- Byte 96/144 ---
# Buscando byte 95, usando 0 A's, comparando bloque 5
# Target block: 4aa90ffea7a5d48449a025884c2af99d
# ✓ Encontrado: \x0a
#
# Progreso (96 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f6620476f642773206368696c6472656e206172652c20696e20666163742c0a626172656c792070726573656e7461626c652e0a
# ASCII: All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
#
#
# --- Byte 97/144 ---
# Buscando byte 96, usando 15 A's, comparando bloque 6
# Target block: 0c80791bdc74e156b2fc062fdeb711c5
# ✓ Encontrado: \x09
#
# --- Byte 98/144 ---
# Buscando byte 97, usando 14 A's, comparando bloque 6
# Target block: 8239179aeaaf73e7e74e55f0cd61c1ac
# ✓ Encontrado: \x09
#
# --- Byte 99/144 ---
# Buscando byte 98, usando 13 A's, comparando bloque 6
# Target block: 6c293e222ff83befbeead0e7ea70d42c
# ✓ Encontrado: -
#
# --- Byte 100/144 ---
# Buscando byte 99, usando 12 A's, comparando bloque 6
# Target block: 884463b72c8c9dca131d05558dcd47d3
# ✓ Encontrado: -
#
# --- Byte 101/144 ---
# Buscando byte 100, usando 11 A's, comparando bloque 6
# Target block: 97c0d9d611c041b2442233f2d596d67a
# ✓ Encontrado:
#
# --- Byte 102/144 ---
# Buscando byte 101, usando 10 A's, comparando bloque 6
# Target block: 5b870bb45989ebefe65d54c7640e0eeb
# ✓ Encontrado: F
#
# --- Byte 103/144 ---
# Buscando byte 102, usando 9 A's, comparando bloque 6
# Target block: 5b13838325d9dc97f6c736f6764c87a1
# ✓ Encontrado: r
#
# --- Byte 104/144 ---
# Buscando byte 103, usando 8 A's, comparando bloque 6
# Target block: f5df393eebb3eda4614ebe1cc956eaa5
# ✓ Encontrado: a
#
# --- Byte 105/144 ---
# Buscando byte 104, usando 7 A's, comparando bloque 6
# Target block: 907cded320a3a3d62b86ce6391e776a1
# ✓ Encontrado: n
#
# --- Byte 106/144 ---
# Buscando byte 105, usando 6 A's, comparando bloque 6
# Target block: 15f9b2d09e6edb873f91c26eefc6f6cb
# ✓ Encontrado:
#
# --- Byte 107/144 ---
# Buscando byte 106, usando 5 A's, comparando bloque 6
# Target block: 97adaf76b5b383f8bbee8a5c5cb5d7ef
# ✓ Encontrado: L
#
# --- Byte 108/144 ---
# Buscando byte 107, usando 4 A's, comparando bloque 6
# Target block: 81dc9d9f46226f4d9d1411a409be3d73
# ✓ Encontrado: e
#
# --- Byte 109/144 ---
# Buscando byte 108, usando 3 A's, comparando bloque 6
# Target block: f37b33a480690eedfa36617855b37a90
# ✓ Encontrado: b
#
# --- Byte 110/144 ---
# Buscando byte 109, usando 2 A's, comparando bloque 6
# Target block: bb3ee3cb7eca286659e0ed70000305eb
# ✓ Encontrado: o
#
# --- Byte 111/144 ---
# Buscando byte 110, usando 1 A's, comparando bloque 6
# Target block: 6e46b8a1c3615553d93097b2e87e9f09
# ✓ Encontrado: w
#
# --- Byte 112/144 ---
# Buscando byte 111, usando 0 A's, comparando bloque 6
# Target block: 2a595d1f75d5c457d0f13a4131c32355
# ✓ Encontrado: i
#
# Progreso (112 bytes):
# Hex: 416c6c20476f642773206368696c6472656e20617265206e6f742062656175746966756c2e20204d6f7374206f6620476f642773206368696c6472656e206172652c20696e20666163742c0a626172656c792070726573656e7461626c652e0a09092d2d204672616e204c65626f7769
# ASCII: All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
# 		-- Fran Lebowi
#
# --- Byte 113/144 ---
# Buscando byte 112, usando 15 A's, comparando bloque 7
# Target block: 2c5d40cb3b8b4b1bbb67e5f939059bd6
# ✓ Encontrado: t
#
# --- Byte 114/144 ---
# Buscando byte 113, usando 14 A's, comparando bloque 7
# Target block: 32f55df1c18c9a0817c2738a551f7959
# ✓ Encontrado: z
#
# --- Byte 115/144 ---
# Buscando byte 114, usando 13 A's, comparando bloque 7
# Target block: 92a5e3f561f3f673da20394c10a71288
# ✓ Encontrado: ,
#
# --- Byte 116/144 ---
# Buscando byte 115, usando 12 A's, comparando bloque 7
# Target block: d5cc5a6107fcefb1e056649dd676195c
# ✓ Encontrado:
#
# --- Byte 117/144 ---
# Buscando byte 116, usando 11 A's, comparando bloque 7
# Target block: 4d60b97c9d5581ebf0619687562fee55
# ✓ Encontrado: "
#
# --- Byte 118/144 ---
# Buscando byte 117, usando 10 A's, comparando bloque 7
# Target block: 7aabf08a360eea2f3791dbdeef82750a
# ✓ Encontrado: M
#
# --- Byte 119/144 ---
# Buscando byte 118, usando 9 A's, comparando bloque 7
# Target block: a129ba0d899018aa7c1be8492276b050
# ✓ Encontrado: e
#
# --- Byte 120/144 ---
# Buscando byte 119, usando 8 A's, comparando bloque 7
# Target block: c8d6a02822e1e4fed50e2e897091314c
# ✓ Encontrado: t
#
# --- Byte 121/144 ---
# Buscando byte 120, usando 7 A's, comparando bloque 7
# Target block: 68437c9aee710ef7139291215fdd7bc8
# ✓ Encontrado: r
#
# --- Byte 122/144 ---
# Buscando byte 121, usando 6 A's, comparando bloque 7
# Target block: 818550de06c43d1d9502b3f041166ccb
# ✓ Encontrado: o
#
# --- Byte 123/144 ---
# Buscando byte 122, usando 5 A's, comparando bloque 7
# Target block: 7bfdc5eb1c88f0bed55afd52f9405830
# ✓ Encontrado: p
#
# --- Byte 124/144 ---
# Buscando byte 123, usando 4 A's, comparando bloque 7
# Target block: e0945e62ada4282e291c09deff64eae5
# ✓ Encontrado: o
#
# --- Byte 125/144 ---
# Buscando byte 124, usando 3 A's, comparando bloque 7
# Target block: 1f105ef3839ab10a94cb4df24afb6994
# ✓ Encontrado: l
#
# --- Byte 126/144 ---
# Buscando byte 125, usando 2 A's, comparando bloque 7
# Target block: 4b0fbac31b92db663536ee8bfeda8170
# ✓ Encontrado: i
#
# --- Byte 127/144 ---
# Buscando byte 126, usando 1 A's, comparando bloque 7
# Target block: 85918a9d7d5dea1ced492639d7bba5f4
# ✓ Encontrado: t
#
# --- Byte 128/144 ---
# Buscando byte 127, usando 0 A's, comparando bloque 7
# Target block: 0b557aa86bc0d69f5d659a30bf3227bb
# ✓ Encontrado: a
#
# Progreso (128 bytes):
# Hex: 
# ASCII: All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
# 		-- Fran Lebowitz, "Metropolita
#
# --- Byte 129/144 ---
# Buscando byte 128, usando 15 A's, comparando bloque 8
# Target block: 65a95ceff405b5ab17054bd0b4bf16fa
# ✓ Encontrado: n
#
# --- Byte 130/144 ---
# Buscando byte 129, usando 14 A's, comparando bloque 8
# Target block: d3aa557669be868f3e87863e3fdf5ce9
# ✓ Encontrado:
#
# --- Byte 131/144 ---
# Buscando byte 130, usando 13 A's, comparando bloque 8
# Target block: 88703865c8bd9ee95dc01c12c9a07d5a
# ✓ Encontrado: L
#
# --- Byte 132/144 ---
# Buscando byte 131, usando 12 A's, comparando bloque 8
# Target block: 5e75bae9b11b50b78ac9fe7e71ea307b
# ✓ Encontrado: i
#
# --- Byte 133/144 ---
# Buscando byte 132, usando 11 A's, comparando bloque 8
# Target block: 2ac11c6e098b1a5b44cad4e0ae766936
# ✓ Encontrado: f
#
# --- Byte 134/144 ---
# Buscando byte 133, usando 10 A's, comparando bloque 8
# Target block: cc5de553e411450191690157fc1d3681
# ✓ Encontrado: e
#
# --- Byte 135/144 ---
# Buscando byte 134, usando 9 A's, comparando bloque 8
# Target block: 82fef985a3252d9fce2066ecaeee8bd1
# ✓ Encontrado: "
#
# --- Byte 136/144 ---
# Buscando byte 135, usando 8 A's, comparando bloque 8
# Target block: 1fb2cbc2d224b0054e7547ffa112a638
# ✓ Encontrado: \x01
#
# --- Byte 137/144 ---
# Buscando byte 136, usando 7 A's, comparando bloque 8
# Target block: b63f8ec87815daa88f1995f3a20d4bd8
# ✗ No encontrado
# Fallo en posición 136
# All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
# 		-- Fran Lebowitz, "Metropolitan Life"

# %%
print(secret_extended)
secret_text = secret_extended.decode('utf-8')
print(secret_text)
# Out:
# b'All God\'s children are not beautiful.  Most of God\'s children are, in fact,\nbarely presentable.\n\t\t-- Fran Lebowitz, "Metropolitan Life"\x01'
# All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
# 		-- Fran Lebowitz, "Metropolitan Life"

# %%
secret_clean = secret_extended[:-1]
print(f"Secreto limpio: {secret_clean.decode('utf-8')}")

# Codificar en base64
secret_b64 = base64.b64encode(secret_clean).decode()

# Enviar
response = requests.post(
    answer_url,
    files={'message': secret_clean}
)

print(f"Respuesta: {response.text}")
# Out:
# Secreto limpio: All God's children are not beautiful.  Most of God's children are, in fact,
# barely presentable.
# 		-- Fran Lebowitz, "Metropolitan Life"
# Respuesta: ¡Ganaste!
